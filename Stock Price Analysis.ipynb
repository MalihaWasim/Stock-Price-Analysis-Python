# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2020,1,1)
end = datetime.datetime(2020,4,17)

# %%
google = web.DataReader("GOOGL",'yahoo',start,end)

# %%
google
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  68.433998  67.324501  67.420502  68.433998  27278000  68.433998
# 2020-01-03  68.687500  67.365997  67.400002  68.075996  23408000  68.075996
# 2020-01-06  69.916000  67.550003  67.581497  69.890503  46768000  69.890503
# 2020-01-07  70.175003  69.578003  70.023003  69.755501  34330000  69.755501
# 2020-01-08  70.592499  69.631500  69.740997  70.251999  35314000  70.251999
# ...               ...        ...        ...        ...       ...        ...
# 2020-04-13  60.726002  59.116501  60.075001  60.520500  38702000  60.520500
# 2020-04-14  63.787498  61.426998  61.998501  63.261501  63358000  63.261501
# 2020-04-15  63.755501  61.700001  62.325500  62.865002  42236000  62.865002
# 2020-04-16  63.667999  61.910000  63.356998  62.871498  57896000  62.871498
# 2020-04-17  64.500000  63.299999  64.084999  63.950001  51050000  63.950001
#
# [74 rows x 6 columns]

# %%
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  68.433998  67.324501  67.420502  68.433998  27278000  68.433998
# 2020-01-03  68.687500  67.365997  67.400002  68.075996  23408000  68.075996
# 2020-01-06  69.916000  67.550003  67.581497  69.890503  46768000  69.890503
# 2020-01-07  70.175003  69.578003  70.023003  69.755501  34330000  69.755501
# 2020-01-08  70.592499  69.631500  69.740997  70.251999  35314000  70.251999

# %%
google['Open']
# Out:
# Date
# 2020-01-02    67.420502
# 2020-01-03    67.400002
# 2020-01-06    67.581497
# 2020-01-07    70.023003
# 2020-01-08    69.740997
#                 ...
# 2020-04-13    60.075001
# 2020-04-14    61.998501
# 2020-04-15    62.325500
# 2020-04-16    63.356998
# 2020-04-17    64.084999
# Name: Open, Length: 74, dtype: float64

# %%
google['Open'].plot()
plt.show()

# %%
google['Open'].plot(label = 'GOOGL Open price', figsize=(15,7))
google['Close'].plot(label = 'GOOGL Close price')
google['High'].plot(label = 'GOOGL High price')
google['Low'].plot(label = 'GOOGL Low price')
plt.legend()
plt.title('Google Stock Prices')
plt.ylabel('Stock Price')
plt.show()

# %% [markdown]
# # Volume Traded Visualization

# %%
google['Volume'].plot(figsize=(17,5))
plt.title('Volume Traded by Google')
# Out:
# Text(0.5, 1.0, 'Volume Traded by Google')

# %% [markdown]
# # Stock Market Analysis of FORD, Tesla, GM

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2017,1,1)

# %%
Tesla = web.DataReader("TSLA",'yahoo',start,end)
Ford = web.DataReader("F",'yahoo',start,end)
GM = web.DataReader("GM",'yahoo',start,end)

# %%
Tesla.to_csv('Tesla_Stock.csv')
Ford.to_csv('Ford_Stock.csv')
GM.to_csv('GM_Stock.csv')

# %%
Tesla.head()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2012-01-03  1.966667  1.843333  1.929333  1.872000  13921500   1.872000
# 2012-01-04  1.911333  1.833333  1.880667  1.847333   9451500   1.847333
# 2012-01-05  1.862000  1.790000  1.850667  1.808000  15082500   1.808000
# 2012-01-06  1.852667  1.760667  1.813333  1.794000  14794500   1.794000
# 2012-01-09  1.832667  1.741333  1.800000  1.816667  13455000   1.816667

# %%
Ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.345916
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.458119
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.649521
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.728723
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.788124

# %%
GM.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.232351
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.309465
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.096025
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.674372
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.612680

# %%
Tesla['Open'].plot(label='Tesla',figsize=(15,7))
GM['Open'].plot(label='GM')
Ford['Open'].plot(label='Ford')
plt.ylabel('Stock Price')
plt.title('Stock Prices of Tesla, GM and Ford')
plt.legend()

# %% [markdown]
# # Volume Traded & Interpretations

# %%
Tesla['Volume'].plot(label='Tesla',figsize=(15,7))
GM['Volume'].plot(label='GM')
Ford['Volume'].plot(label='Ford')
plt.ylabel('Volume Traded')
plt.legend()

# %%
Ford.iloc[[Ford['Volume'].argmax()]]
# Out:
#             High    Low   Open  Close       Volume  Adj Close
# Date
# 2013-12-18  16.0  15.17  15.99  15.65  220363000.0  10.801616

# %%
Ford.iloc[470:520]['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Market Cap

# %%
# its a visual representation of a total amount of money being traded around using time series.

# %%
Tesla['Total Traded'] = Tesla['Open'] * Tesla['Volume']

# %%
Tesla.head()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2012-01-03  1.966667  1.843333  1.929333  1.872000  13921500   1.872000
# 2012-01-04  1.911333  1.833333  1.880667  1.847333   9451500   1.847333
# 2012-01-05  1.862000  1.790000  1.850667  1.808000  15082500   1.808000
# 2012-01-06  1.852667  1.760667  1.813333  1.794000  14794500   1.794000
# 2012-01-09  1.832667  1.741333  1.800000  1.816667  13455000   1.816667
#
#             Total Traded
# Date
# 2012-01-03  2.685921e+07
# 2012-01-04  1.777512e+07
# 2012-01-05  2.791269e+07
# 2012-01-06  2.682736e+07
# 2012-01-09  2.421900e+07

# %%
GM['Total Traded'] = GM['Open'] * GM['Volume']

# %%
GM.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.232351
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.309465
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.096025
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.674372
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.612680
#
#             Total Traded
# Date
# 2012-01-03  1.941627e+08
# 2012-01-04  1.653835e+08
# 2012-01-05  3.772807e+08
# 2012-01-06  4.059000e+08
# 2012-01-09  2.803604e+08

# %%
Ford['Total Traded'] = Ford['Open'] * Ford['Volume']

# %%
Ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.345916  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.458119  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.649521  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.728723  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.788124  6.386011e+08

# %%
Tesla['Total Traded'].plot(label='Tesla', figsize=(15,7))
GM['Total Traded'].plot(label='GM', figsize=(15,7))
Ford['Total Traded'].plot(label='Ford', figsize=(15,7))
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
Tesla['Total Traded'].argmax()
# use to get the max size of spike
# Out:
# 538

# %%
Tesla.iloc[[Tesla['Total Traded'].argmax()]]
# Out:
#                  High    Low       Open      Close     Volume  Adj Close  \
# Date
# 2014-02-25  17.280001  15.23  15.333333  16.533333  490225500  16.533333
#
#             Total Traded
# Date
# 2014-02-25  7.516791e+09

# %% [markdown]
# # Moving Average

# %%
GM['Open'].plot(figsize=(15,7))
# MA is used to make graph/series smoother, so craete a new column and set a window of 50 sample
GM['MA50'] = GM['Open'].rolling(50).mean()
GM['MA50'].plot(label='MA50')
GM['MA200'] = GM['Open'].rolling(200).mean()
GM['MA200'].plot(label='MA200')
plt.legend()

# %% [markdown]
# # Correlation and Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_comp = pd.concat([Tesla['Open'],GM['Open'],Ford['Open']],axis=1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Ford Open']

# %%
scatter_matrix(car_comp, figsize =(8,8))
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %% [markdown]
# # Candle Stick Charts

# %%
pip install mpl-finance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

Ford_reset = Ford.loc['2012-01': '2012-01'].reset_index()

Ford_reset['date_ax'] = Ford_reset['Date'].apply(lambda date: date2num(date))
Ford_values = [tuple(vals) for vals in Ford_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()
candlestick_ohlc(ax, Ford_values, width = 0.6, colorup='g', colordown='r')
# Out:
# ([<matplotlib.lines.Line2D at 0x239ad6fe9a0>,
# ...
#   <matplotlib.patches.Rectangle at 0x239ad823190>])

# %% [markdown]
# # Daily Percentage Change

# %% [markdown]
# # rt = (pt / pt-1) - 1

# %%
# if gain then the ratio should be greater than 1,
# if loss otherwise
# calculate percentage returns and plot histograms 
# based on histograms we can see which stock is stable

# %%
# u want to invest in stocks that are stable in long run
Tesla['returns'] = (Tesla['Close']/Tesla['Close'].shift(1)) - 1

# %%
Tesla.head()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2012-01-03  1.966667  1.843333  1.929333  1.872000  13921500   1.872000
# 2012-01-04  1.911333  1.833333  1.880667  1.847333   9451500   1.847333
# 2012-01-05  1.862000  1.790000  1.850667  1.808000  15082500   1.808000
# 2012-01-06  1.852667  1.760667  1.813333  1.794000  14794500   1.794000
# 2012-01-09  1.832667  1.741333  1.800000  1.816667  13455000   1.816667
#
#             Total Traded   returns
# Date
# 2012-01-03  2.685921e+07       NaN
# 2012-01-04  1.777512e+07 -0.013177
# 2012-01-05  2.791269e+07 -0.021292
# 2012-01-06  2.682736e+07 -0.007743
# 2012-01-09  2.421900e+07  0.012635

# %%
GM['returns'] = (GM['Close']/GM['Close'].shift(1)) - 1
GM.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.232351
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.309465
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.096025
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.674372
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.612680
#
#             Total Traded  MA50  MA200   returns
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490

# %%
Ford['returns'] = (Ford['Close']/Ford['Close'].shift(1)) - 1
Ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.345916  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.458119  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.649521  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.728723  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.788124  6.386011e+08
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
Ford['returns'].hist(bins=50)
# to check volatility of Ford Stocks
# the more flatter it is, the more volatile this stock is
# the width of the bell shaped is related to the standard deviation of the distribution
# the higher S.D is, the more variance we have
# Out:
# <AxesSubplot:>

# %%
GM['returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
Tesla['returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# lets plot all three in one graph
Tesla['returns'].hist(bins=199, label='Tesla',alpha=0.5,figsize=(13,6))
GM['returns'].hist(bins=199, label='GM',alpha=0.5)
Ford['returns'].hist(bins=199, label='Ford',alpha=0.5)
plt.legend()
# this is historgram not normalized

# %%
Tesla['returns'].plot(kind='kde',label='Tesla', figsize=(15,6))
GM['returns'].plot(kind='kde',label='GM')
Ford['returns'].plot(kind='kde',label='Ford')
plt.legend()
# this is normalized curve

# %% [markdown]
# ### Box Plot

# %%
box_df = pd.concat([Tesla['returns'],GM['returns'],Ford['returns']],axis=1)
box_df.columns=['Tesla returns', 'GM returns', 'Ford Returns']
box_df.plot(kind='box', figsize=(16,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cumulative Return

# %% [markdown]
# ### it = (1+rt)it-1

# %%
# if it is above 1, then profits otherwise loss
Tesla['Cumulative Return'] = (1 + Tesla['returns']).cumprod()

# %%
Tesla.head()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2012-01-03  1.966667  1.843333  1.929333  1.872000  13921500   1.872000
# 2012-01-04  1.911333  1.833333  1.880667  1.847333   9451500   1.847333
# 2012-01-05  1.862000  1.790000  1.850667  1.808000  15082500   1.808000
# 2012-01-06  1.852667  1.760667  1.813333  1.794000  14794500   1.794000
# 2012-01-09  1.832667  1.741333  1.800000  1.816667  13455000   1.816667
#
#             Total Traded   returns  Cumulative Return
# Date
# 2012-01-03  2.685921e+07       NaN                NaN
# 2012-01-04  1.777512e+07 -0.013177           0.986823
# 2012-01-05  2.791269e+07 -0.021292           0.965812
# 2012-01-06  2.682736e+07 -0.007743           0.958333
# 2012-01-09  2.421900e+07  0.012635           0.970442

# %%
GM['Cumulative Return'] = (1 + GM['returns']).cumprod()
GM.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.232351
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.309465
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.096025
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.674372
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.612680
#
#             Total Traded  MA50  MA200   returns  Cumulative Return
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN                NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751           1.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227           1.053207
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829           1.088836
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490           1.085036

# %%
Ford['Cumulative Return'] = (1 + Ford['returns']).cumprod()
Ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.345916  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.458119  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.649521  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.728723  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.788124  6.386011e+08
#
#              returns  Cumulative Return
# Date
# 2012-01-03       NaN                NaN
# 2012-01-04  0.015274           1.015274
# 2012-01-05  0.025664           1.041330
# 2012-01-06  0.010354           1.052111
# 2012-01-09  0.007686           1.060198

# %%
Tesla['Cumulative Return'].plot(label='Tesla',figsize=(15,7))
GM['Cumulative Return'].plot(label='GM')
Ford['Cumulative Return'].plot(label='Ford')
plt.legend()

# %%
# which stock is showing highest return from $1, see heads
# it is clearly showing Tesla from above figure
